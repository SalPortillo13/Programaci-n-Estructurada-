# %%
from ipywidgets  import interact
import ipywidgets as widgets

def f(x):
   return x**2


interact(f, x=10)
# Out:
# interactive(children=(IntSlider(value=10, description='x', max=30, min=-10), Output()), _dom_classes=('widget-…
# <function __main__.f(x)>

# %%
from ipywidgets import widgets
from IPython.display import display

button = widgets.Button(description="Click Me!")
output = widgets.Output()

display(button, output)

def on_button_clicked(b):
 with output:
  print("Button clicked.")
button.on_click(on_button_clicked)
# Out:
#   File "<ipython-input-8-0d0a4a0243fe>", line 11
#     print("Button clicked.")
#                             ^
# IndentationError: expected an indented block after 'with' statement on line 10

# %%
 from ipywidgets import widgets
 from IPython.display import display

 slider = widgets.IntSlider(
      value=7,
      min=0,
      max=10,
      step=1,
      description='Value:',
     disabled=False,
     continuous_update=False,
     orientation='horizontal',
    readout=True,
     readout_format='d'
 )

 display(slider)

 def on_value_change(change):
    print(f"Slider value changed to: {change['new']}")

 slider.observe(on_value_change, names='value')
# Out:
# IntSlider(value=7, continuous_update=False, description='Value:', max=10)
# Slider value changed to: 10
# Slider value changed to: 0
# Slider value changed to: 3
# Slider value changed to: 4

# %%
from ipywidgets import widgets
from IPython.display import display

text_input = widgets.Text(
    value='Hello World!',
    placeholder='Type something',
    description='Text:',
    disabled=False
)

output_area = widgets.Output()

display(text_input)
display(output_area)

def on_text_change(change):
    with output_area:
        output_area.clear_output()  # Clear previous output
        print(f"You typed: {change['new']}")

text_input.observe(on_text_change, names='value')
# Out:
# Text(value='Hello World!', description='Text:', placeholder='Type something')
# Output()

# %%
from ipywidgets import widgets
from IPython.display import display

dropdown = widgets.Dropdown(
    options=['Python', 'Arturo', 'C++', 'JavaScript', 'Julia'],
    value='Python',
    description='Language:',
    disabled=False,
)

display(dropdown)

def on_dropdown_change(change):
    print(f"Selected language: {change['new']}")

dropdown.observe(on_dropdown_change, names='value')
# Out:
# Dropdown(description='Language:', options=('Python', 'Arturo', 'C++', 'JavaScript', 'Julia'), value='Python')
# Selected language: C++
# Selected language: Julia
# Selected language: Python

# %%
from ipywidgets import widgets
from IPython.display import display

button1 = widgets.Button(description="Button 1")
button2 = widgets.Button(description="Button 2")
output = widgets.Output()

display(button1)
display(button2)
display(output)

def on_button1_clicked(b):
    with output:
        output.clear_output()
        print("Button 1 clicked!")

def on_button2_clicked(b):
    with output:
        output.clear_output()
        print("Button 2 clicked!")

button1.on_click(on_button1_clicked)
button2.on_click(on_button2_clicked)
# Out:
# Button(description='Button 1', style=ButtonStyle())
# Button(description='Button 2', style=ButtonStyle())
# Output()

# %%
import requests
url = 'https://www.stat.berkeley.edu/~spector/python.pdf'

response = requests.get(url)
file_Path = 'python.pdf'

if response.status_code == 200:
    with open(file_Path, 'wb') as file:
        file.write(response.content)

    print('File downloaded successfully')
else:
    print('Failed to download file')
# Out:
# File downloaded successfully

# %%
# !pip install Pillow
# !pip install rembg

# Store path of the image in the variable input_path
input_path = '/content/beelx.png'

# Store path of the output image in the variable output_path
output_path = '/content/bee2x.png'

# Processing the image
input = PIL.Image.open(input_path)

# Removing the background from the given Image
output = rembg.remove(input)

# Saving the image in the given path
output.save(output_path)

# %%
import os # Importing the 'os' module

def list_folders(start_path='/', output_file='folders_list.txt'):
    excluded_dirs = {'/bin', '/boot', '/dev', '/etc', '/lib', '/lib64', '/proc', '/run', '/sbin', '/sys', '/tmp', '/var'}

    with open(output_file, 'w') as f:
        for root, dirs, files in os.walk(start_path):
            dirs[:] = [d for d in dirs if os.path.join(root, d) not in excluded_dirs]
            for directory in dirs:
                folder_path = os.path.join(root, directory)
                print(folder_path)
                f.write(folder_path + '\n')

if __name__ == "__main__":
    list_folders('/')  # Starts from the root directory
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# /tools/google-cloud-sdk/lib/surface/metastore/operations
# /tools/google-cloud-sdk/lib/surface/metastore/services
# /tools/google-cloud-sdk/lib/surface/metastore/federations/__pycache__
# /tools/google-cloud-sdk/lib/surface/metastore/locations/__pycache__
# /tools/google-cloud-sdk/lib/surface/metastore/operations/__pycache__
# /tools/google-cloud-sdk/lib/surface/metastore/services/imports
# /tools/google-cloud-sdk/lib/surface/metastore/services/import
# /tools/google-cloud-sdk/lib/surface/metastore/services/backups
# /tools/google-cloud-sdk/lib/surface/metastore/services/databases
# /tools/google-cloud-sdk/lib/surface/metastore/services/migrations
# /tools/google-cloud-sdk/lib/surface/metastore/services/__pycache__
# /tools/google-cloud-sdk/lib/surface/metastore/services/export
# /tools/google-cloud-sdk/lib/surface/metastore/services/imports/__pycache__
# /tools/google-cloud-sdk/lib/surface/metastore/services/import/__pycache__
# /tools/google-cloud-sdk/lib/surface/metastore/services/backups/__pycache__
# /tools/google-cloud-sdk/lib/surface/metastore/services/databases/tables
# /tools/google-cloud-sdk/lib/surface/metastore/services/databases/__pycache__
# /tools/google-cloud-sdk/lib/surface/metastore/services/databases/tables/__pycache__
# /tools/google-cloud-sdk/lib/surface/metastore/services/migrations/__pycache__
# /tools/google-cloud-sdk/lib/surface/metastore/services/export/__pycache__
# /tools/google-cloud-sdk/lib/surface/billing/projects
# /tools/google-cloud-sdk/lib/surface/billing/budgets
# /tools/google-cloud-sdk/lib/surface/billing/accounts
# /tools/google-cloud-sdk/lib/surface/billing/__pycache__
# /tools/google-cloud-sdk/lib/surface/billing/projects/__pycache__
# /tools/google-cloud-sdk/lib/surface/billing/budgets/__pycache__
# /tools/google-cloud-sdk/lib/surface/billing/accounts/projects
# /tools/google-cloud-sdk/lib/surface/billing/accounts/__pycache__
# /tools/google-cloud-sdk/lib/surface/billing/accounts/projects/__pycache__
# /tools/google-cloud-sdk/lib/surface/spanner/samples
# /tools/google-cloud-sdk/lib/surface/spanner/backups
# /tools/google-cloud-sdk/lib/surface/spanner/databases
# /tools/google-cloud-sdk/lib/surface/spanner/instances
# /tools/google-cloud-sdk/lib/surface/spanner/ssd_caches
# /tools/google-cloud-sdk/lib/surface/spanner/instance_partitions
# /tools/google-cloud-sdk/lib/surface/spanner/migrate
# /tools/google-cloud-sdk/lib/surface/spanner/backup_schedules
# /tools/google-cloud-sdk/lib/surface/spanner/__pycache__
# /tools/google-cloud-sdk/lib/surface/spanner/operations
# /tools/google-cloud-sdk/lib/surface/spanner/rows
# /tools/google-cloud-sdk/lib/surface/spanner/instance_configs
# /tools/google-cloud-sdk/lib/surface/spanner/samples/__pycache__
# /tools/google-cloud-sdk/lib/surface/spanner/backups/__pycache__
# /tools/google-cloud-sdk/lib/surface/spanner/databases/roles
# /tools/google-cloud-sdk/lib/surface/spanner/databases/ddl
# /tools/google-cloud-sdk/lib/surface/spanner/databases/__pycache__
# /tools/google-cloud-sdk/lib/surface/spanner/databases/config
# /tools/google-cloud-sdk/lib/surface/spanner/databases/splits
# /tools/google-cloud-sdk/lib/surface/spanner/databases/sessions
# /tools/google-cloud-sdk/lib/surface/spanner/databases/roles/__pycache__
# /tools/google-cloud-sdk/lib/surface/spanner/databases/ddl/__pycache__
# /tools/google-cloud-sdk/lib/surface/spanner/databases/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/spanner/databases/splits/__pycache__
# /tools/google-cloud-sdk/lib/surface/spanner/databases/sessions/__pycache__
# /tools/google-cloud-sdk/lib/surface/spanner/instances/__pycache__
# /tools/google-cloud-sdk/lib/surface/spanner/instances/config
# /tools/google-cloud-sdk/lib/surface/spanner/instances/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/spanner/ssd_caches/__pycache__
# /tools/google-cloud-sdk/lib/surface/spanner/instance_partitions/__pycache__
# /tools/google-cloud-sdk/lib/surface/spanner/migrate/__pycache__
# /tools/google-cloud-sdk/lib/surface/spanner/backup_schedules/__pycache__
# /tools/google-cloud-sdk/lib/surface/spanner/operations/__pycache__
# /tools/google-cloud-sdk/lib/surface/spanner/rows/__pycache__
# /tools/google-cloud-sdk/lib/surface/spanner/instance_configs/__pycache__
# /tools/google-cloud-sdk/lib/surface/organizations/__pycache__
# /tools/google-cloud-sdk/lib/surface/composer/environments
# /tools/google-cloud-sdk/lib/surface/composer/__pycache__
# /tools/google-cloud-sdk/lib/surface/composer/operations
# /tools/google-cloud-sdk/lib/surface/composer/environments/storage
# /tools/google-cloud-sdk/lib/surface/composer/environments/user_workloads_secrets
# /tools/google-cloud-sdk/lib/surface/composer/environments/user_workloads_config_maps
# /tools/google-cloud-sdk/lib/surface/composer/environments/__pycache__
# /tools/google-cloud-sdk/lib/surface/composer/environments/snapshots
# /tools/google-cloud-sdk/lib/surface/composer/environments/storage/dags
# /tools/google-cloud-sdk/lib/surface/composer/environments/storage/data
# /tools/google-cloud-sdk/lib/surface/composer/environments/storage/plugins
# /tools/google-cloud-sdk/lib/surface/composer/environments/storage/__pycache__
# /tools/google-cloud-sdk/lib/surface/composer/environments/storage/dags/__pycache__
# /tools/google-cloud-sdk/lib/surface/composer/environments/storage/data/__pycache__
# /tools/google-cloud-sdk/lib/surface/composer/environments/storage/plugins/__pycache__
# /tools/google-cloud-sdk/lib/surface/composer/environments/user_workloads_secrets/__pycache__
# /tools/google-cloud-sdk/lib/surface/composer/environments/user_workloads_config_maps/__pycache__
# /tools/google-cloud-sdk/lib/surface/composer/environments/snapshots/__pycache__
# /tools/google-cloud-sdk/lib/surface/composer/operations/__pycache__
# /tools/google-cloud-sdk/lib/surface/memcache/regions
# /tools/google-cloud-sdk/lib/surface/memcache/instances
# /tools/google-cloud-sdk/lib/surface/memcache/__pycache__
# /tools/google-cloud-sdk/lib/surface/memcache/operations
# /tools/google-cloud-sdk/lib/surface/memcache/regions/__pycache__
# /tools/google-cloud-sdk/lib/surface/memcache/instances/__pycache__
# /tools/google-cloud-sdk/lib/surface/memcache/instances/config
# /tools/google-cloud-sdk/lib/surface/memcache/instances/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/memcache/operations/__pycache__
# /tools/google-cloud-sdk/lib/surface/lustre/instances
# /tools/google-cloud-sdk/lib/surface/lustre/__pycache__
# /tools/google-cloud-sdk/lib/surface/lustre/operations
# /tools/google-cloud-sdk/lib/surface/lustre/instances/__pycache__
# /tools/google-cloud-sdk/lib/surface/lustre/instances/_partials
# /tools/google-cloud-sdk/lib/surface/lustre/operations/__pycache__
# /tools/google-cloud-sdk/lib/surface/lustre/operations/_partials
# /tools/google-cloud-sdk/lib/surface/network_connectivity/policy_based_routes
# /tools/google-cloud-sdk/lib/surface/network_connectivity/hubs
# /tools/google-cloud-sdk/lib/surface/network_connectivity/service_connection_policies
# /tools/google-cloud-sdk/lib/surface/network_connectivity/locations
# /tools/google-cloud-sdk/lib/surface/network_connectivity/regional_endpoints
# /tools/google-cloud-sdk/lib/surface/network_connectivity/internal_ranges
# /tools/google-cloud-sdk/lib/surface/network_connectivity/spokes
# /tools/google-cloud-sdk/lib/surface/network_connectivity/__pycache__
# /tools/google-cloud-sdk/lib/surface/network_connectivity/operations
# /tools/google-cloud-sdk/lib/surface/network_connectivity/policy_based_routes/__pycache__
# /tools/google-cloud-sdk/lib/surface/network_connectivity/hubs/route_tables
# /tools/google-cloud-sdk/lib/surface/network_connectivity/hubs/__pycache__
# /tools/google-cloud-sdk/lib/surface/network_connectivity/hubs/groups
# /tools/google-cloud-sdk/lib/surface/network_connectivity/hubs/route_tables/routes
# /tools/google-cloud-sdk/lib/surface/network_connectivity/hubs/route_tables/__pycache__
# /tools/google-cloud-sdk/lib/surface/network_connectivity/hubs/route_tables/routes/__pycache__
# /tools/google-cloud-sdk/lib/surface/network_connectivity/hubs/groups/__pycache__
# /tools/google-cloud-sdk/lib/surface/network_connectivity/service_connection_policies/__pycache__
# /tools/google-cloud-sdk/lib/surface/network_connectivity/locations/__pycache__
# /tools/google-cloud-sdk/lib/surface/network_connectivity/regional_endpoints/__pycache__
# /tools/google-cloud-sdk/lib/surface/network_connectivity/internal_ranges/__pycache__
# /tools/google-cloud-sdk/lib/surface/network_connectivity/spokes/linked_interconnect_attachments
# /tools/google-cloud-sdk/lib/surface/network_connectivity/spokes/linked_router_appliances
# /tools/google-cloud-sdk/lib/surface/network_connectivity/spokes/linked_vpn_tunnels
# /tools/google-cloud-sdk/lib/surface/network_connectivity/spokes/linked_producer_vpc_network
# /tools/google-cloud-sdk/lib/surface/network_connectivity/spokes/__pycache__
# /tools/google-cloud-sdk/lib/surface/network_connectivity/spokes/linked_vpc_network
# /tools/google-cloud-sdk/lib/surface/network_connectivity/spokes/gateways
# /tools/google-cloud-sdk/lib/surface/network_connectivity/spokes/linked_interconnect_attachments/__pycache__
# /tools/google-cloud-sdk/lib/surface/network_connectivity/spokes/linked_router_appliances/__pycache__
# /tools/google-cloud-sdk/lib/surface/network_connectivity/spokes/linked_vpn_tunnels/__pycache__
# /tools/google-cloud-sdk/lib/surface/network_connectivity/spokes/linked_producer_vpc_network/__pycache__
# /tools/google-cloud-sdk/lib/surface/network_connectivity/spokes/linked_vpc_network/__pycache__
# /tools/google-cloud-sdk/lib/surface/network_connectivity/spokes/gateways/advertised_routes
# /tools/google-cloud-sdk/lib/surface/network_connectivity/spokes/gateways/__pycache__
# /tools/google-cloud-sdk/lib/surface/network_connectivity/spokes/gateways/advertised_routes/__pycache__
# /tools/google-cloud-sdk/lib/surface/network_connectivity/operations/__pycache__
# /tools/google-cloud-sdk/lib/surface/spectrum_access/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/network_edge_security_services
# /tools/google-cloud-sdk/lib/surface/compute/network_profiles
# /tools/google-cloud-sdk/lib/surface/compute/multi_migs
# /tools/google-cloud-sdk/lib/surface/compute/storage_pool_types
# /tools/google-cloud-sdk/lib/surface/compute/regions
# /tools/google-cloud-sdk/lib/surface/compute/public_advertised_prefixes
# /tools/google-cloud-sdk/lib/surface/compute/tpus
# /tools/google-cloud-sdk/lib/surface/compute/firewall_policies
# /tools/google-cloud-sdk/lib/surface/compute/shared_vpc
# /tools/google-cloud-sdk/lib/surface/compute/vpn_tunnels
# /tools/google-cloud-sdk/lib/surface/compute/queued_resources
# /tools/google-cloud-sdk/lib/surface/compute/storage_pools
# /tools/google-cloud-sdk/lib/surface/compute/org_security_policies
# /tools/google-cloud-sdk/lib/surface/compute/disk_types
# /tools/google-cloud-sdk/lib/surface/compute/routes
# /tools/google-cloud-sdk/lib/surface/compute/commitments
# /tools/google-cloud-sdk/lib/surface/compute/os_config
# /tools/google-cloud-sdk/lib/surface/compute/target_instances
# /tools/google-cloud-sdk/lib/surface/compute/forwarding_rules
# /tools/google-cloud-sdk/lib/surface/compute/external_vpn_gateways
# /tools/google-cloud-sdk/lib/surface/compute/target_vpn_gateways
# /tools/google-cloud-sdk/lib/surface/compute/security_policies
# /tools/google-cloud-sdk/lib/surface/compute/networks
# /tools/google-cloud-sdk/lib/surface/compute/url_maps
# /tools/google-cloud-sdk/lib/surface/compute/target_ssl_proxies
# /tools/google-cloud-sdk/lib/surface/compute/backend_buckets
# /tools/google-cloud-sdk/lib/surface/compute/target_pools
# /tools/google-cloud-sdk/lib/surface/compute/reservations
# /tools/google-cloud-sdk/lib/surface/compute/network_attachments
# /tools/google-cloud-sdk/lib/surface/compute/target_https_proxies
# /tools/google-cloud-sdk/lib/surface/compute/interconnects
# /tools/google-cloud-sdk/lib/surface/compute/backend_services
# /tools/google-cloud-sdk/lib/surface/compute/routers
# /tools/google-cloud-sdk/lib/surface/compute/instance_groups
# /tools/google-cloud-sdk/lib/surface/compute/addresses
# /tools/google-cloud-sdk/lib/surface/compute/instances
# /tools/google-cloud-sdk/lib/surface/compute/os_login
# /tools/google-cloud-sdk/lib/surface/compute/disks
# /tools/google-cloud-sdk/lib/surface/compute/service_attachments
# /tools/google-cloud-sdk/lib/surface/compute/target_tcp_proxies
# /tools/google-cloud-sdk/lib/surface/compute/firewall_rules
# /tools/google-cloud-sdk/lib/surface/compute/ssl_certificates
# /tools/google-cloud-sdk/lib/surface/compute/network_endpoint_groups
# /tools/google-cloud-sdk/lib/surface/compute/future_reservations
# /tools/google-cloud-sdk/lib/surface/compute/sole_tenancy
# /tools/google-cloud-sdk/lib/surface/compute/project_info
# /tools/google-cloud-sdk/lib/surface/compute/snapshot_settings
# /tools/google-cloud-sdk/lib/surface/compute/project_zonal_metadata
# /tools/google-cloud-sdk/lib/surface/compute/instant_snapshots
# /tools/google-cloud-sdk/lib/surface/compute/accelerator_types
# /tools/google-cloud-sdk/lib/surface/compute/disk_settings
# /tools/google-cloud-sdk/lib/surface/compute/target_grpc_proxies
# /tools/google-cloud-sdk/lib/surface/compute/images
# /tools/google-cloud-sdk/lib/surface/compute/instance_templates
# /tools/google-cloud-sdk/lib/surface/compute/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/operations
# /tools/google-cloud-sdk/lib/surface/compute/machine_types
# /tools/google-cloud-sdk/lib/surface/compute/network_firewall_policies
# /tools/google-cloud-sdk/lib/surface/compute/packet_mirrorings
# /tools/google-cloud-sdk/lib/surface/compute/diagnose
# /tools/google-cloud-sdk/lib/surface/compute/http_health_checks
# /tools/google-cloud-sdk/lib/surface/compute/machine_images
# /tools/google-cloud-sdk/lib/surface/compute/ssl_policies
# /tools/google-cloud-sdk/lib/surface/compute/resource_policies
# /tools/google-cloud-sdk/lib/surface/compute/snapshots
# /tools/google-cloud-sdk/lib/surface/compute/public_delegated_prefixes
# /tools/google-cloud-sdk/lib/surface/compute/https_health_checks
# /tools/google-cloud-sdk/lib/surface/compute/vpn_gateways
# /tools/google-cloud-sdk/lib/surface/compute/target_http_proxies
# /tools/google-cloud-sdk/lib/surface/compute/instance_settings
# /tools/google-cloud-sdk/lib/surface/compute/zones
# /tools/google-cloud-sdk/lib/surface/compute/health_checks
# /tools/google-cloud-sdk/lib/surface/compute/network_edge_security_services/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/network_profiles/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/multi_migs/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/storage_pool_types/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/regions/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/public_advertised_prefixes/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/tpus/versions
# /tools/google-cloud-sdk/lib/surface/compute/tpus/tpu_vm
# /tools/google-cloud-sdk/lib/surface/compute/tpus/queued_resources
# /tools/google-cloud-sdk/lib/surface/compute/tpus/topologies
# /tools/google-cloud-sdk/lib/surface/compute/tpus/reservations
# /tools/google-cloud-sdk/lib/surface/compute/tpus/locations
# /tools/google-cloud-sdk/lib/surface/compute/tpus/accelerator_types
# /tools/google-cloud-sdk/lib/surface/compute/tpus/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/tpus/execution_groups
# /tools/google-cloud-sdk/lib/surface/compute/tpus/versions/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/tpus/tpu_vm/versions
# /tools/google-cloud-sdk/lib/surface/compute/tpus/tpu_vm/service_identity
# /tools/google-cloud-sdk/lib/surface/compute/tpus/tpu_vm/accelerator_types
# /tools/google-cloud-sdk/lib/surface/compute/tpus/tpu_vm/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/tpus/tpu_vm/versions/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/tpus/tpu_vm/service_identity/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/tpus/tpu_vm/accelerator_types/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/tpus/queued_resources/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/tpus/topologies/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/tpus/reservations/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/tpus/locations/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/tpus/accelerator_types/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/tpus/execution_groups/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/firewall_policies/mirroring_rules
# /tools/google-cloud-sdk/lib/surface/compute/firewall_policies/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/firewall_policies/rules
# /tools/google-cloud-sdk/lib/surface/compute/firewall_policies/associations
# /tools/google-cloud-sdk/lib/surface/compute/firewall_policies/mirroring_rules/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/firewall_policies/rules/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/firewall_policies/associations/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/shared_vpc/associated_projects
# /tools/google-cloud-sdk/lib/surface/compute/shared_vpc/organizations
# /tools/google-cloud-sdk/lib/surface/compute/shared_vpc/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/shared_vpc/associated_projects/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/shared_vpc/organizations/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/vpn_tunnels/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/vpn_tunnels/config
# /tools/google-cloud-sdk/lib/surface/compute/vpn_tunnels/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/queued_resources/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/storage_pools/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/org_security_policies/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/org_security_policies/rules
# /tools/google-cloud-sdk/lib/surface/compute/org_security_policies/associations
# /tools/google-cloud-sdk/lib/surface/compute/org_security_policies/rules/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/org_security_policies/associations/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/disk_types/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/routes/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/commitments/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/os_config/os_policy_assignments
# /tools/google-cloud-sdk/lib/surface/compute/os_config/patch_deployments
# /tools/google-cloud-sdk/lib/surface/compute/os_config/patch_jobs
# /tools/google-cloud-sdk/lib/surface/compute/os_config/os_policy_assignment_reports
# /tools/google-cloud-sdk/lib/surface/compute/os_config/policy_orchestrators
# /tools/google-cloud-sdk/lib/surface/compute/os_config/guest_policies
# /tools/google-cloud-sdk/lib/surface/compute/os_config/inventories
# /tools/google-cloud-sdk/lib/surface/compute/os_config/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/os_config/vulnerability_reports
# /tools/google-cloud-sdk/lib/surface/compute/os_config/project_feature_settings
# /tools/google-cloud-sdk/lib/surface/compute/os_config/instance_os_policies_compliances
# /tools/google-cloud-sdk/lib/surface/compute/os_config/os_policy_assignments/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/os_config/os_policy_assignments/operations
# /tools/google-cloud-sdk/lib/surface/compute/os_config/os_policy_assignments/operations/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/os_config/patch_deployments/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/os_config/patch_jobs/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/os_config/os_policy_assignment_reports/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/os_config/policy_orchestrators/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/os_config/guest_policies/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/os_config/inventories/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/os_config/vulnerability_reports/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/os_config/project_feature_settings/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/os_config/instance_os_policies_compliances/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/target_instances/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/target_instances/config
# /tools/google-cloud-sdk/lib/surface/compute/target_instances/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/forwarding_rules/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/forwarding_rules/config
# /tools/google-cloud-sdk/lib/surface/compute/forwarding_rules/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/external_vpn_gateways/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/target_vpn_gateways/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/target_vpn_gateways/config
# /tools/google-cloud-sdk/lib/surface/compute/target_vpn_gateways/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/security_policies/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/security_policies/rules
# /tools/google-cloud-sdk/lib/surface/compute/security_policies/rules/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/networks/peerings
# /tools/google-cloud-sdk/lib/surface/compute/networks/subnets
# /tools/google-cloud-sdk/lib/surface/compute/networks/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/networks/vpc_access
# /tools/google-cloud-sdk/lib/surface/compute/networks/peerings/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/networks/subnets/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/networks/subnets/config
# /tools/google-cloud-sdk/lib/surface/compute/networks/subnets/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/networks/vpc_access/locations
# /tools/google-cloud-sdk/lib/surface/compute/networks/vpc_access/connectors
# /tools/google-cloud-sdk/lib/surface/compute/networks/vpc_access/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/networks/vpc_access/operations
# /tools/google-cloud-sdk/lib/surface/compute/networks/vpc_access/locations/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/networks/vpc_access/connectors/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/networks/vpc_access/operations/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/url_maps/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/url_maps/config
# /tools/google-cloud-sdk/lib/surface/compute/url_maps/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/target_ssl_proxies/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/target_ssl_proxies/config
# /tools/google-cloud-sdk/lib/surface/compute/target_ssl_proxies/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/backend_buckets/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/backend_buckets/config
# /tools/google-cloud-sdk/lib/surface/compute/backend_buckets/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/target_pools/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/target_pools/config
# /tools/google-cloud-sdk/lib/surface/compute/target_pools/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/reservations/blocks
# /tools/google-cloud-sdk/lib/surface/compute/reservations/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/reservations/blocks/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/network_attachments/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/target_https_proxies/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/target_https_proxies/config
# /tools/google-cloud-sdk/lib/surface/compute/target_https_proxies/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/interconnects/macsec
# /tools/google-cloud-sdk/lib/surface/compute/interconnects/cross_site_networks
# /tools/google-cloud-sdk/lib/surface/compute/interconnects/attachments
# /tools/google-cloud-sdk/lib/surface/compute/interconnects/wire_groups
# /tools/google-cloud-sdk/lib/surface/compute/interconnects/locations
# /tools/google-cloud-sdk/lib/surface/compute/interconnects/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/interconnects/groups
# /tools/google-cloud-sdk/lib/surface/compute/interconnects/remote_locations
# /tools/google-cloud-sdk/lib/surface/compute/interconnects/macsec/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/interconnects/cross_site_networks/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/interconnects/attachments/provider
# /tools/google-cloud-sdk/lib/surface/compute/interconnects/attachments/dedicated
# /tools/google-cloud-sdk/lib/surface/compute/interconnects/attachments/partner
# /tools/google-cloud-sdk/lib/surface/compute/interconnects/attachments/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/interconnects/attachments/groups
# /tools/google-cloud-sdk/lib/surface/compute/interconnects/attachments/provider/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/interconnects/attachments/dedicated/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/interconnects/attachments/partner/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/interconnects/attachments/groups/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/interconnects/wire_groups/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/interconnects/locations/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/interconnects/groups/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/interconnects/remote_locations/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/backend_services/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/routers/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/routers/nats
# /tools/google-cloud-sdk/lib/surface/compute/routers/nats/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/routers/nats/rules
# /tools/google-cloud-sdk/lib/surface/compute/routers/nats/rules/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/instance_groups/managed
# /tools/google-cloud-sdk/lib/surface/compute/instance_groups/unmanaged
# /tools/google-cloud-sdk/lib/surface/compute/instance_groups/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/instance_groups/managed/all_instances_config
# /tools/google-cloud-sdk/lib/surface/compute/instance_groups/managed/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/instance_groups/managed/instance_configs
# /tools/google-cloud-sdk/lib/surface/compute/instance_groups/managed/resize_requests
# /tools/google-cloud-sdk/lib/surface/compute/instance_groups/managed/rolling_action
# /tools/google-cloud-sdk/lib/surface/compute/instance_groups/managed/all_instances_config/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/instance_groups/managed/instance_configs/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/instance_groups/managed/resize_requests/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/instance_groups/managed/rolling_action/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/instance_groups/unmanaged/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/addresses/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/addresses/config
# /tools/google-cloud-sdk/lib/surface/compute/addresses/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/instances/ops_agents
# /tools/google-cloud-sdk/lib/surface/compute/instances/vulnerabilities
# /tools/google-cloud-sdk/lib/surface/compute/instances/os_inventory
# /tools/google-cloud-sdk/lib/surface/compute/instances/network_interfaces
# /tools/google-cloud-sdk/lib/surface/compute/instances/bulk
# /tools/google-cloud-sdk/lib/surface/compute/instances/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/instances/config
# /tools/google-cloud-sdk/lib/surface/compute/instances/ops_agents/policies
# /tools/google-cloud-sdk/lib/surface/compute/instances/ops_agents/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/instances/ops_agents/policies/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/instances/vulnerabilities/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/instances/os_inventory/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/instances/network_interfaces/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/instances/bulk/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/instances/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/os_login/ssh_keys
# /tools/google-cloud-sdk/lib/surface/compute/os_login/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/os_login/ssh_keys/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/disks/bulk
# /tools/google-cloud-sdk/lib/surface/compute/disks/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/disks/config
# /tools/google-cloud-sdk/lib/surface/compute/disks/bulk/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/disks/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/service_attachments/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/target_tcp_proxies/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/target_tcp_proxies/config
# /tools/google-cloud-sdk/lib/surface/compute/target_tcp_proxies/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/firewall_rules/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/firewall_rules/config
# /tools/google-cloud-sdk/lib/surface/compute/firewall_rules/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/ssl_certificates/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/network_endpoint_groups/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/future_reservations/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/sole_tenancy/node_groups
# /tools/google-cloud-sdk/lib/surface/compute/sole_tenancy/node_templates
# /tools/google-cloud-sdk/lib/surface/compute/sole_tenancy/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/sole_tenancy/node_types
# /tools/google-cloud-sdk/lib/surface/compute/sole_tenancy/node_groups/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/sole_tenancy/node_templates/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/sole_tenancy/node_types/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/project_info/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/snapshot_settings/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/project_zonal_metadata/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/instant_snapshots/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/accelerator_types/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/disk_settings/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/target_grpc_proxies/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/target_grpc_proxies/config
# /tools/google-cloud-sdk/lib/surface/compute/target_grpc_proxies/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/images/vulnerabilities
# /tools/google-cloud-sdk/lib/surface/compute/images/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/images/packages
# /tools/google-cloud-sdk/lib/surface/compute/images/vulnerabilities/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/images/packages/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/instance_templates/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/operations/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/machine_types/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/network_firewall_policies/mirroring_rules
# /tools/google-cloud-sdk/lib/surface/compute/network_firewall_policies/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/network_firewall_policies/rules
# /tools/google-cloud-sdk/lib/surface/compute/network_firewall_policies/associations
# /tools/google-cloud-sdk/lib/surface/compute/network_firewall_policies/mirroring_rules/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/network_firewall_policies/rules/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/network_firewall_policies/associations/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/packet_mirrorings/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/diagnose/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/http_health_checks/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/machine_images/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/ssl_policies/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/ssl_policies/config
# /tools/google-cloud-sdk/lib/surface/compute/ssl_policies/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/resource_policies/create
# /tools/google-cloud-sdk/lib/surface/compute/resource_policies/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/resource_policies/update
# /tools/google-cloud-sdk/lib/surface/compute/resource_policies/create/vm_maintenance
# /tools/google-cloud-sdk/lib/surface/compute/resource_policies/create/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/resource_policies/create/vm_maintenance/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/resource_policies/update/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/snapshots/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/public_delegated_prefixes/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/public_delegated_prefixes/delegated_sub_prefixes
# /tools/google-cloud-sdk/lib/surface/compute/public_delegated_prefixes/delegated_sub_prefixes/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/https_health_checks/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/vpn_gateways/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/vpn_gateways/config
# /tools/google-cloud-sdk/lib/surface/compute/vpn_gateways/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/target_http_proxies/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/target_http_proxies/config
# /tools/google-cloud-sdk/lib/surface/compute/target_http_proxies/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/instance_settings/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/zones/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/health_checks/create
# /tools/google-cloud-sdk/lib/surface/compute/health_checks/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/health_checks/update
# /tools/google-cloud-sdk/lib/surface/compute/health_checks/create/__pycache__
# /tools/google-cloud-sdk/lib/surface/compute/health_checks/update/__pycache__
# /tools/google-cloud-sdk/lib/surface/certificate_manager/issuance_configs
# /tools/google-cloud-sdk/lib/surface/certificate_manager/dns_authorizations
# /tools/google-cloud-sdk/lib/surface/certificate_manager/trust_configs
# /tools/google-cloud-sdk/lib/surface/certificate_manager/certificates
# /tools/google-cloud-sdk/lib/surface/certificate_manager/__pycache__
# /tools/google-cloud-sdk/lib/surface/certificate_manager/operations
# /tools/google-cloud-sdk/lib/surface/certificate_manager/maps
# /tools/google-cloud-sdk/lib/surface/certificate_manager/issuance_configs/__pycache__
# /tools/google-cloud-sdk/lib/surface/certificate_manager/dns_authorizations/__pycache__
# /tools/google-cloud-sdk/lib/surface/certificate_manager/trust_configs/__pycache__
# /tools/google-cloud-sdk/lib/surface/certificate_manager/certificates/__pycache__
# /tools/google-cloud-sdk/lib/surface/certificate_manager/operations/__pycache__
# /tools/google-cloud-sdk/lib/surface/certificate_manager/maps/entries
# /tools/google-cloud-sdk/lib/surface/certificate_manager/maps/__pycache__
# /tools/google-cloud-sdk/lib/surface/certificate_manager/maps/entries/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/governance_rules
# /tools/google-cloud-sdk/lib/surface/dataplex/entries
# /tools/google-cloud-sdk/lib/surface/dataplex/metadata_jobs
# /tools/google-cloud-sdk/lib/surface/dataplex/assets
# /tools/google-cloud-sdk/lib/surface/dataplex/data_attribute_bindings
# /tools/google-cloud-sdk/lib/surface/dataplex/data_taxonomies
# /tools/google-cloud-sdk/lib/surface/dataplex/environments
# /tools/google-cloud-sdk/lib/surface/dataplex/content
# /tools/google-cloud-sdk/lib/surface/dataplex/entry_types
# /tools/google-cloud-sdk/lib/surface/dataplex/lakes
# /tools/google-cloud-sdk/lib/surface/dataplex/encryption_config
# /tools/google-cloud-sdk/lib/surface/dataplex/entry_groups
# /tools/google-cloud-sdk/lib/surface/dataplex/glossaries
# /tools/google-cloud-sdk/lib/surface/dataplex/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/datascans
# /tools/google-cloud-sdk/lib/surface/dataplex/datascan
# /tools/google-cloud-sdk/lib/surface/dataplex/tasks
# /tools/google-cloud-sdk/lib/surface/dataplex/aspect_types
# /tools/google-cloud-sdk/lib/surface/dataplex/zones
# /tools/google-cloud-sdk/lib/surface/dataplex/governance_rules/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/entries/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/metadata_jobs/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/assets/actions
# /tools/google-cloud-sdk/lib/surface/dataplex/assets/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/assets/actions/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/data_attribute_bindings/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/data_taxonomies/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/data_taxonomies/attributes
# /tools/google-cloud-sdk/lib/surface/dataplex/data_taxonomies/attributes/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/environments/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/environments/sessions
# /tools/google-cloud-sdk/lib/surface/dataplex/environments/sessions/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/content/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/entry_types/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/lakes/actions
# /tools/google-cloud-sdk/lib/surface/dataplex/lakes/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/lakes/actions/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/encryption_config/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/entry_groups/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/glossaries/categories
# /tools/google-cloud-sdk/lib/surface/dataplex/glossaries/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/glossaries/terms
# /tools/google-cloud-sdk/lib/surface/dataplex/glossaries/categories/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/glossaries/terms/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/datascans/create
# /tools/google-cloud-sdk/lib/surface/dataplex/datascans/jobs
# /tools/google-cloud-sdk/lib/surface/dataplex/datascans/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/datascans/update
# /tools/google-cloud-sdk/lib/surface/dataplex/datascans/create/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/datascans/jobs/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/datascans/update/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/datascan/jobs
# /tools/google-cloud-sdk/lib/surface/dataplex/datascan/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/datascan/jobs/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/tasks/jobs
# /tools/google-cloud-sdk/lib/surface/dataplex/tasks/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/tasks/jobs/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/aspect_types/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/zones/actions
# /tools/google-cloud-sdk/lib/surface/dataplex/zones/__pycache__
# /tools/google-cloud-sdk/lib/surface/dataplex/zones/actions/__pycache__
# /tools/google-cloud-sdk/lib/surface/workbench/instances
# /tools/google-cloud-sdk/lib/surface/workbench/__pycache__
# /tools/google-cloud-sdk/lib/surface/workbench/executions
# /tools/google-cloud-sdk/lib/surface/workbench/instances/__pycache__
# /tools/google-cloud-sdk/lib/surface/workbench/executions/__pycache__
# /tools/google-cloud-sdk/lib/surface/firebase/test
# /tools/google-cloud-sdk/lib/surface/firebase/__pycache__
# /tools/google-cloud-sdk/lib/surface/firebase/test/android
# /tools/google-cloud-sdk/lib/surface/firebase/test/network_profiles
# /tools/google-cloud-sdk/lib/surface/firebase/test/ios
# /tools/google-cloud-sdk/lib/surface/firebase/test/__pycache__
# /tools/google-cloud-sdk/lib/surface/firebase/test/ip_blocks
# /tools/google-cloud-sdk/lib/surface/firebase/test/android/locales
# /tools/google-cloud-sdk/lib/surface/firebase/test/android/versions
# /tools/google-cloud-sdk/lib/surface/firebase/test/android/models
# /tools/google-cloud-sdk/lib/surface/firebase/test/android/__pycache__
# /tools/google-cloud-sdk/lib/surface/firebase/test/android/locales/__pycache__
# /tools/google-cloud-sdk/lib/surface/firebase/test/android/versions/__pycache__
# /tools/google-cloud-sdk/lib/surface/firebase/test/android/models/__pycache__
# /tools/google-cloud-sdk/lib/surface/firebase/test/network_profiles/__pycache__
# /tools/google-cloud-sdk/lib/surface/firebase/test/ios/locales
# /tools/google-cloud-sdk/lib/surface/firebase/test/ios/versions
# /tools/google-cloud-sdk/lib/surface/firebase/test/ios/models
# /tools/google-cloud-sdk/lib/surface/firebase/test/ios/__pycache__
# /tools/google-cloud-sdk/lib/surface/firebase/test/ios/locales/__pycache__
# /tools/google-cloud-sdk/lib/surface/firebase/test/ios/versions/__pycache__
# /tools/google-cloud-sdk/lib/surface/firebase/test/ios/models/__pycache__
# /tools/google-cloud-sdk/lib/surface/firebase/test/ip_blocks/__pycache__
# /tools/google-cloud-sdk/lib/surface/active_directory/domains
# /tools/google-cloud-sdk/lib/surface/active_directory/peerings
# /tools/google-cloud-sdk/lib/surface/active_directory/__pycache__
# /tools/google-cloud-sdk/lib/surface/active_directory/operations
# /tools/google-cloud-sdk/lib/surface/active_directory/domains/migration
# /tools/google-cloud-sdk/lib/surface/active_directory/domains/backups
# /tools/google-cloud-sdk/lib/surface/active_directory/domains/sql_integrations
# /tools/google-cloud-sdk/lib/surface/active_directory/domains/__pycache__
# /tools/google-cloud-sdk/lib/surface/active_directory/domains/trusts
# /tools/google-cloud-sdk/lib/surface/active_directory/domains/migration/__pycache__
# /tools/google-cloud-sdk/lib/surface/active_directory/domains/backups/__pycache__
# /tools/google-cloud-sdk/lib/surface/active_directory/domains/sql_integrations/__pycache__
# /tools/google-cloud-sdk/lib/surface/active_directory/domains/trusts/__pycache__
# /tools/google-cloud-sdk/lib/surface/active_directory/peerings/__pycache__
# /tools/google-cloud-sdk/lib/surface/active_directory/operations/__pycache__
# /tools/google-cloud-sdk/lib/surface/oracle_database/db_system_shapes
# /tools/google-cloud-sdk/lib/surface/oracle_database/cloud_vm_clusters
# /tools/google-cloud-sdk/lib/surface/oracle_database/autonomous_database_backups
# /tools/google-cloud-sdk/lib/surface/oracle_database/gi_versions
# /tools/google-cloud-sdk/lib/surface/oracle_database/entitlements
# /tools/google-cloud-sdk/lib/surface/oracle_database/autonomous_databases
# /tools/google-cloud-sdk/lib/surface/oracle_database/autonomous_db_versions
# /tools/google-cloud-sdk/lib/surface/oracle_database/__pycache__
# /tools/google-cloud-sdk/lib/surface/oracle_database/operations
# /tools/google-cloud-sdk/lib/surface/oracle_database/autonomous_database_character_sets
# /tools/google-cloud-sdk/lib/surface/oracle_database/cloud_exadata_infrastructures
# /tools/google-cloud-sdk/lib/surface/oracle_database/db_system_shapes/__pycache__
# /tools/google-cloud-sdk/lib/surface/oracle_database/db_system_shapes/_partials
# /tools/google-cloud-sdk/lib/surface/oracle_database/cloud_vm_clusters/db_nodes
# /tools/google-cloud-sdk/lib/surface/oracle_database/cloud_vm_clusters/__pycache__
# /tools/google-cloud-sdk/lib/surface/oracle_database/cloud_vm_clusters/_partials
# /tools/google-cloud-sdk/lib/surface/oracle_database/cloud_vm_clusters/db_nodes/__pycache__
# /tools/google-cloud-sdk/lib/surface/oracle_database/cloud_vm_clusters/db_nodes/_partials
# /tools/google-cloud-sdk/lib/surface/oracle_database/autonomous_database_backups/__pycache__
# /tools/google-cloud-sdk/lib/surface/oracle_database/gi_versions/__pycache__
# /tools/google-cloud-sdk/lib/surface/oracle_database/gi_versions/_partials
# /tools/google-cloud-sdk/lib/surface/oracle_database/entitlements/__pycache__
# /tools/google-cloud-sdk/lib/surface/oracle_database/entitlements/_partials
# /tools/google-cloud-sdk/lib/surface/oracle_database/autonomous_databases/__pycache__
# /tools/google-cloud-sdk/lib/surface/oracle_database/autonomous_databases/_partials
# /tools/google-cloud-sdk/lib/surface/oracle_database/autonomous_db_versions/__pycache__
# /tools/google-cloud-sdk/lib/surface/oracle_database/autonomous_db_versions/_partials
# /tools/google-cloud-sdk/lib/surface/oracle_database/operations/__pycache__
# /tools/google-cloud-sdk/lib/surface/oracle_database/operations/_partials
# /tools/google-cloud-sdk/lib/surface/oracle_database/autonomous_database_character_sets/__pycache__
# /tools/google-cloud-sdk/lib/surface/oracle_database/autonomous_database_character_sets/_partials
# /tools/google-cloud-sdk/lib/surface/oracle_database/cloud_exadata_infrastructures/db_servers
# /tools/google-cloud-sdk/lib/surface/oracle_database/cloud_exadata_infrastructures/__pycache__
# /tools/google-cloud-sdk/lib/surface/oracle_database/cloud_exadata_infrastructures/_partials
# /tools/google-cloud-sdk/lib/surface/oracle_database/cloud_exadata_infrastructures/db_servers/__pycache__
# /tools/google-cloud-sdk/lib/surface/oracle_database/cloud_exadata_infrastructures/db_servers/_partials
# /tools/google-cloud-sdk/lib/surface/config/universe_descriptors
# /tools/google-cloud-sdk/lib/surface/config/configurations
# /tools/google-cloud-sdk/lib/surface/config/virtualenv
# /tools/google-cloud-sdk/lib/surface/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/config/universe_descriptors/__pycache__
# /tools/google-cloud-sdk/lib/surface/config/configurations/__pycache__
# /tools/google-cloud-sdk/lib/surface/config/virtualenv/__pycache__
# /tools/google-cloud-sdk/lib/surface/secrets/versions
# /tools/google-cloud-sdk/lib/surface/secrets/locations
# /tools/google-cloud-sdk/lib/surface/secrets/__pycache__
# /tools/google-cloud-sdk/lib/surface/secrets/config
# /tools/google-cloud-sdk/lib/surface/secrets/replication
# /tools/google-cloud-sdk/lib/surface/secrets/versions/__pycache__
# /tools/google-cloud-sdk/lib/surface/secrets/versions/config
# /tools/google-cloud-sdk/lib/surface/secrets/versions/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/secrets/locations/__pycache__
# /tools/google-cloud-sdk/lib/surface/secrets/config/__pycache__
# /tools/google-cloud-sdk/lib/surface/secrets/replication/__pycache__
# /tools/google-cloud-sdk/lib/surface/notebooks/environments
# /tools/google-cloud-sdk/lib/surface/notebooks/instances
# /tools/google-cloud-sdk/lib/surface/notebooks/locations
# /tools/google-cloud-sdk/lib/surface/notebooks/runtimes
# /tools/google-cloud-sdk/lib/surface/notebooks/__pycache__
# /tools/google-cloud-sdk/lib/surface/notebooks/environments/__pycache__
# /tools/google-cloud-sdk/lib/surface/notebooks/instances/__pycache__
# /tools/google-cloud-sdk/lib/surface/notebooks/locations/__pycache__
# /tools/google-cloud-sdk/lib/surface/notebooks/runtimes/__pycache__
# /tools/google-cloud-sdk/lib/surface/pam/entitlements
# /tools/google-cloud-sdk/lib/surface/pam/__pycache__
# /tools/google-cloud-sdk/lib/surface/pam/operations
# /tools/google-cloud-sdk/lib/surface/pam/grants
# /tools/google-cloud-sdk/lib/surface/pam/entitlements/__pycache__
# /tools/google-cloud-sdk/lib/surface/pam/operations/__pycache__
# /tools/google-cloud-sdk/lib/surface/pam/grants/__pycache__
# /tools/google-cloud-sdk/lib/surface/service_directory/endpoints
# /tools/google-cloud-sdk/lib/surface/service_directory/locations
# /tools/google-cloud-sdk/lib/surface/service_directory/namespaces
# /tools/google-cloud-sdk/lib/surface/service_directory/__pycache__
# /tools/google-cloud-sdk/lib/surface/service_directory/services
# /tools/google-cloud-sdk/lib/surface/service_directory/endpoints/__pycache__
# /tools/google-cloud-sdk/lib/surface/service_directory/locations/__pycache__
# /tools/google-cloud-sdk/lib/surface/service_directory/namespaces/__pycache__
# /tools/google-cloud-sdk/lib/surface/service_directory/services/__pycache__
# /tools/google-cloud-sdk/lib/surface/vmware/private_connections
# /tools/google-cloud-sdk/lib/surface/vmware/networks
# /tools/google-cloud-sdk/lib/surface/vmware/dns_bind_permission
# /tools/google-cloud-sdk/lib/surface/vmware/sddc
# /tools/google-cloud-sdk/lib/surface/vmware/locations
# /tools/google-cloud-sdk/lib/surface/vmware/private_clouds
# /tools/google-cloud-sdk/lib/surface/vmware/__pycache__
# ...
# /datalab/web/pyright/typeshed-fallback/stubs/invoke/invoke
# /datalab/web/pyright/typeshed-fallback/stubs/invoke/invoke/parser
# /datalab/web/pyright/typeshed-fallback/stubs/invoke/invoke/completion
# /datalab/web/pyright/typeshed-fallback/stubs/editdistance/editdistance
# /datalab/web/pyright/typeshed-fallback/stubs/typed-ast/typed_ast
# /datalab/web/pyright/typeshed-fallback/stubs/boto/boto
# /datalab/web/pyright/typeshed-fallback/stubs/boto/boto/elb
# /datalab/web/pyright/typeshed-fallback/stubs/boto/boto/ec2
# /datalab/web/pyright/typeshed-fallback/stubs/boto/boto/s3
# /datalab/web/pyright/typeshed-fallback/stubs/boto/boto/kms
# /datalab/web/pyright/typeshed-fallback/stubs/Flask-SQLAlchemy/flask_sqlalchemy
# /datalab/web/pyright/typeshed-fallback/stubs/babel/babel
# /datalab/web/pyright/typeshed-fallback/stubs/babel/babel/messages
# /datalab/web/pyright/typeshed-fallback/stubs/babel/babel/localtime
# /datalab/web/pyright/typeshed-fallback/stubs/toml/toml
# /datalab/web/pyright/typeshed-fallback/stubs/PyYAML/yaml
# /datalab/web/pyright/typeshed-fallback/stubs/flake8-simplify/flake8_simplify
# /datalab/web/pyright/typeshed-fallback/stubs/urllib3/urllib3
# /datalab/web/pyright/typeshed-fallback/stubs/urllib3/urllib3/util
# /datalab/web/pyright/typeshed-fallback/stubs/urllib3/urllib3/contrib
# /datalab/web/pyright/typeshed-fallback/stubs/urllib3/urllib3/packages
# /datalab/web/pyright/typeshed-fallback/stubs/urllib3/urllib3/packages/ssl_match_hostname
# /datalab/web/pyright/typeshed-fallback/stubs/chardet/chardet
# /datalab/web/pyright/typeshed-fallback/stubs/tqdm/tqdm
# /datalab/web/pyright/typeshed-fallback/stubs/tqdm/tqdm/contrib
# /datalab/web/pyright/typeshed-fallback/stubs/vobject/vobject
# /datalab/web/pyright/typeshed-fallback/stubs/colorama/colorama
# /datalab/web/pyright/typeshed-fallback/stubs/cryptography/cryptography
# /datalab/web/pyright/typeshed-fallback/stubs/cryptography/cryptography/hazmat
# /datalab/web/pyright/typeshed-fallback/stubs/cryptography/cryptography/x509
# /datalab/web/pyright/typeshed-fallback/stubs/cryptography/cryptography/hazmat/primitives
# /datalab/web/pyright/typeshed-fallback/stubs/cryptography/cryptography/hazmat/backends
# /datalab/web/pyright/typeshed-fallback/stubs/cryptography/cryptography/hazmat/bindings
# /datalab/web/pyright/typeshed-fallback/stubs/cryptography/cryptography/hazmat/primitives/ciphers
# /datalab/web/pyright/typeshed-fallback/stubs/cryptography/cryptography/hazmat/primitives/asymmetric
# /datalab/web/pyright/typeshed-fallback/stubs/cryptography/cryptography/hazmat/primitives/twofactor
# /datalab/web/pyright/typeshed-fallback/stubs/cryptography/cryptography/hazmat/primitives/serialization
# /datalab/web/pyright/typeshed-fallback/stubs/cryptography/cryptography/hazmat/primitives/kdf
# /datalab/web/pyright/typeshed-fallback/stubs/cryptography/cryptography/hazmat/bindings/openssl
# /datalab/web/pyright/typeshed-fallback/stubs/commonmark/commonmark
# /datalab/web/pyright/typeshed-fallback/stubs/commonmark/commonmark/render
# /datalab/web/pyright/typeshed-fallback/stubs/aws-xray-sdk/aws_xray_sdk
# /datalab/web/pyright/typeshed-fallback/stubs/aws-xray-sdk/aws_xray_sdk/core
# /datalab/web/pyright/typeshed-fallback/stubs/aws-xray-sdk/aws_xray_sdk/core/models
# /datalab/web/pyright/typeshed-fallback/stubs/aws-xray-sdk/aws_xray_sdk/core/exceptions
# /datalab/web/pyright/typeshed-fallback/stubs/aws-xray-sdk/aws_xray_sdk/core/emitters
# /datalab/web/pyright/typeshed-fallback/stubs/aws-xray-sdk/aws_xray_sdk/core/sampling
# /datalab/web/pyright/typeshed-fallback/stubs/aws-xray-sdk/aws_xray_sdk/core/plugins
# /datalab/web/pyright/typeshed-fallback/stubs/aws-xray-sdk/aws_xray_sdk/core/utils
# /datalab/web/pyright/typeshed-fallback/stubs/aws-xray-sdk/aws_xray_sdk/core/streaming
# /datalab/web/pyright/typeshed-fallback/stubs/aws-xray-sdk/aws_xray_sdk/core/sampling/local
# /datalab/web/pyright/typeshed-fallback/stubs/pysftp/pysftp
# /datalab/web/pyright/typeshed-fallback/stubs/aiofiles/aiofiles
# /datalab/web/pyright/typeshed-fallback/stubs/aiofiles/aiofiles/threadpool
# /datalab/web/pyright/typeshed-fallback/stubs/aiofiles/aiofiles/tempfile
# /datalab/web/pyright/typeshed-fallback/stubs/hdbcli/hdbcli
# /datalab/web/pyright/typeshed-fallback/stubs/fpdf2/fpdf
# /datalab/web/pyright/typeshed-fallback/stubs/gdb/gdb
# /datalab/web/pyright/typeshed-fallback/stubs/passpy/passpy
# /datalab/web/pyright/typeshed-fallback/stubs/annoy/annoy
# /datalab/web/pyright/typeshed-fallback/stubs/pynput/pynput
# /datalab/web/pyright/typeshed-fallback/stubs/pynput/pynput/keyboard
# /datalab/web/pyright/typeshed-fallback/stubs/pynput/pynput/mouse
# /datalab/web/pyright/typeshed-fallback/stubs/python-slugify/slugify
# /datalab/web/pyright/typeshed-fallback/stubs/regex/regex
# /datalab/web/pyright/typeshed-fallback/stubs/bleach/bleach
# /datalab/web/pyright/typeshed-fallback/stubs/docutils/docutils
# /datalab/web/pyright/typeshed-fallback/stubs/docutils/docutils/languages
# /datalab/web/pyright/typeshed-fallback/stubs/docutils/docutils/readers
# /datalab/web/pyright/typeshed-fallback/stubs/docutils/docutils/writers
# /datalab/web/pyright/typeshed-fallback/stubs/docutils/docutils/parsers
# /datalab/web/pyright/typeshed-fallback/stubs/docutils/docutils/utils
# /datalab/web/pyright/typeshed-fallback/stubs/docutils/docutils/transforms
# /datalab/web/pyright/typeshed-fallback/stubs/docutils/docutils/parsers/rst
# /datalab/web/pyright/typeshed-fallback/stubs/docutils/docutils/parsers/rst/directives
# /datalab/web/pyright/typeshed-fallback/stubs/cachetools/cachetools
# /datalab/web/pyright/typeshed-fallback/stubs/click-spinner/click_spinner
# /datalab/web/pyright/typeshed-fallback/stubs/stripe/stripe
# /datalab/web/pyright/typeshed-fallback/stubs/stripe/stripe/api_resources
# /datalab/web/pyright/typeshed-fallback/stubs/stripe/stripe/api_resources/sigma
# /datalab/web/pyright/typeshed-fallback/stubs/stripe/stripe/api_resources/abstract
# /datalab/web/pyright/typeshed-fallback/stubs/stripe/stripe/api_resources/reporting
# /datalab/web/pyright/typeshed-fallback/stubs/stripe/stripe/api_resources/checkout
# /datalab/web/pyright/typeshed-fallback/stubs/stripe/stripe/api_resources/billing_portal
# /datalab/web/pyright/typeshed-fallback/stubs/stripe/stripe/api_resources/radar
# /datalab/web/pyright/typeshed-fallback/stubs/stripe/stripe/api_resources/terminal
# /datalab/web/pyright/typeshed-fallback/stubs/stripe/stripe/api_resources/issuing
# /datalab/web/pyright/typeshed-fallback/stubs/stripe/stripe/api_resources/identity
# /datalab/web/pyright/typeshed-fallback/stubs/psutil/psutil
# /datalab/web/pyright/typeshed-fallback/stubs/simplejson/simplejson
# /datalab/web/pyright/typeshed-fallback/stubs/pyOpenSSL/OpenSSL
# /datalab/web/pyright/typeshed-fallback/stubs/setuptools/pkg_resources
# /datalab/web/pyright/typeshed-fallback/stubs/setuptools/setuptools
# /datalab/web/pyright/typeshed-fallback/stubs/setuptools/setuptools/_distutils
# /datalab/web/pyright/typeshed-fallback/stubs/setuptools/setuptools/extern
# /datalab/web/pyright/typeshed-fallback/stubs/setuptools/setuptools/command
# /datalab/web/pyright/typeshed-fallback/stubs/setuptools/setuptools/_distutils/command
# /datalab/web/pyright/typeshed-fallback/stubs/Deprecated/deprecated
# /datalab/web/pyright/typeshed-fallback/stubs/ttkthemes/ttkthemes
# /datalab/web/pyright/typeshed-fallback/stubs/httplib2/httplib2
# /datalab/web/pyright/typeshed-fallback/stubs/jmespath/jmespath
# /datalab/web/pyright/typeshed-fallback/stubs/psycopg2/psycopg2
# /datalab/web/pyright/typeshed-fallback/stubs/croniter/croniter
# /datalab/web/pyright/typeshed-fallback/stubs/waitress/waitress
# /datalab/web/pyright/typeshed-fallback/stubs/emoji/emoji
# /datalab/web/pyright/typeshed-fallback/stubs/emoji/emoji/unicode_codes
# /datalab/web/pyright/typeshed-fallback/stubs/slumber/slumber
# /datalab/web/pyright/typeshed-fallback/stubs/ldap3/ldap3
# /datalab/web/pyright/typeshed-fallback/stubs/ldap3/ldap3/operation
# /datalab/web/pyright/typeshed-fallback/stubs/ldap3/ldap3/abstract
# /datalab/web/pyright/typeshed-fallback/stubs/ldap3/ldap3/strategy
# /datalab/web/pyright/typeshed-fallback/stubs/ldap3/ldap3/protocol
# /datalab/web/pyright/typeshed-fallback/stubs/ldap3/ldap3/core
# /datalab/web/pyright/typeshed-fallback/stubs/ldap3/ldap3/utils
# /datalab/web/pyright/typeshed-fallback/stubs/ldap3/ldap3/extend
# /datalab/web/pyright/typeshed-fallback/stubs/ldap3/ldap3/protocol/formatters
# /datalab/web/pyright/typeshed-fallback/stubs/ldap3/ldap3/protocol/sasl
# /datalab/web/pyright/typeshed-fallback/stubs/ldap3/ldap3/protocol/schemas
# /datalab/web/pyright/typeshed-fallback/stubs/ldap3/ldap3/extend/microsoft
# /datalab/web/pyright/typeshed-fallback/stubs/ldap3/ldap3/extend/standard
# /datalab/web/pyright/typeshed-fallback/stubs/ldap3/ldap3/extend/novell
# /datalab/web/pyright/typeshed-fallback/stubs/openpyxl/openpyxl
# /datalab/web/pyright/typeshed-fallback/stubs/openpyxl/openpyxl/workbook
# /datalab/web/pyright/typeshed-fallback/stubs/openpyxl/openpyxl/worksheet
# /datalab/web/pyright/typeshed-fallback/stubs/openpyxl/openpyxl/styles
# /datalab/web/pyright/typeshed-fallback/stubs/openpyxl/openpyxl/writer
# /datalab/web/pyright/typeshed-fallback/stubs/openpyxl/openpyxl/compat
# /datalab/web/pyright/typeshed-fallback/stubs/openpyxl/openpyxl/formatting
# /datalab/web/pyright/typeshed-fallback/stubs/openpyxl/openpyxl/reader
# /datalab/web/pyright/typeshed-fallback/stubs/openpyxl/openpyxl/xml
# /datalab/web/pyright/typeshed-fallback/stubs/openpyxl/openpyxl/chart
# /datalab/web/pyright/typeshed-fallback/stubs/openpyxl/openpyxl/descriptors
# /datalab/web/pyright/typeshed-fallback/stubs/openpyxl/openpyxl/pivot
# /datalab/web/pyright/typeshed-fallback/stubs/openpyxl/openpyxl/formula
# /datalab/web/pyright/typeshed-fallback/stubs/openpyxl/openpyxl/utils
# /datalab/web/pyright/typeshed-fallback/stubs/openpyxl/openpyxl/cell
# /datalab/web/pyright/typeshed-fallback/stubs/openpyxl/openpyxl/chartsheet
# /datalab/web/pyright/typeshed-fallback/stubs/openpyxl/openpyxl/drawing
# /datalab/web/pyright/typeshed-fallback/stubs/openpyxl/openpyxl/packaging
# /datalab/web/pyright/typeshed-fallback/stubs/openpyxl/openpyxl/comments
# /datalab/web/pyright/typeshed-fallback/stubs/openpyxl/openpyxl/workbook/external_link
# /datalab/web/pyright/typeshed-fallback/stubs/flake8-plugin-utils/flake8_plugin_utils
# /datalab/web/pyright/typeshed-fallback/stubs/flake8-plugin-utils/flake8_plugin_utils/utils
# /datalab/web/pyright/typeshed-fallback/stubs/mysqlclient/MySQLdb
# /datalab/web/pyright/typeshed-fallback/stubs/mysqlclient/MySQLdb/constants
# /datalab/web/pyright/typeshed-fallback/stubs/Send2Trash/send2trash
# /datalab/web/pyright/typeshed-fallback/stubs/chevron/chevron
# /datalab/web/pyright/typeshed-fallback/stubs/python-nmap/nmap
# /datalab/web/pyright/typeshed-fallback/stubs/zxcvbn/zxcvbn
# /datalab/web/pyright/typeshed-fallback/stubs/whatthepatch/whatthepatch
# /datalab/web/pyright/typeshed-fallback/stubs/protobuf/google
# /datalab/web/pyright/typeshed-fallback/stubs/protobuf/google/protobuf
# /datalab/web/pyright/typeshed-fallback/stubs/protobuf/google/protobuf/util
# /datalab/web/pyright/typeshed-fallback/stubs/protobuf/google/protobuf/internal
# /datalab/web/pyright/typeshed-fallback/stubs/protobuf/google/protobuf/compiler
# /datalab/web/pyright/typeshed-fallback/stubs/braintree/braintree
# /datalab/web/pyright/typeshed-fallback/stubs/braintree/braintree/util
# /datalab/web/pyright/typeshed-fallback/stubs/braintree/braintree/dispute_details
# /datalab/web/pyright/typeshed-fallback/stubs/braintree/braintree/exceptions
# /datalab/web/pyright/typeshed-fallback/stubs/braintree/braintree/merchant_account
# /datalab/web/pyright/typeshed-fallback/stubs/braintree/braintree/exceptions/http
# /datalab/web/pyright/typeshed-fallback/stdlib/json
# /datalab/web/pyright/typeshed-fallback/stdlib/_typeshed
# /datalab/web/pyright/typeshed-fallback/stdlib/asyncio
# /datalab/web/pyright/typeshed-fallback/stdlib/venv
# /datalab/web/pyright/typeshed-fallback/stdlib/dbm
# /datalab/web/pyright/typeshed-fallback/stdlib/msilib
# /datalab/web/pyright/typeshed-fallback/stdlib/logging
# /datalab/web/pyright/typeshed-fallback/stdlib/zoneinfo
# /datalab/web/pyright/typeshed-fallback/stdlib/urllib
# /datalab/web/pyright/typeshed-fallback/stdlib/collections
# /datalab/web/pyright/typeshed-fallback/stdlib/concurrent
# /datalab/web/pyright/typeshed-fallback/stdlib/importlib
# /datalab/web/pyright/typeshed-fallback/stdlib/email
# /datalab/web/pyright/typeshed-fallback/stdlib/distutils
# /datalab/web/pyright/typeshed-fallback/stdlib/os
# /datalab/web/pyright/typeshed-fallback/stdlib/wsgiref
# /datalab/web/pyright/typeshed-fallback/stdlib/xml
# /datalab/web/pyright/typeshed-fallback/stdlib/http
# /datalab/web/pyright/typeshed-fallback/stdlib/pydoc_data
# /datalab/web/pyright/typeshed-fallback/stdlib/ctypes
# /datalab/web/pyright/typeshed-fallback/stdlib/multiprocessing
# /datalab/web/pyright/typeshed-fallback/stdlib/tkinter
# /datalab/web/pyright/typeshed-fallback/stdlib/unittest
# /datalab/web/pyright/typeshed-fallback/stdlib/lib2to3
# /datalab/web/pyright/typeshed-fallback/stdlib/encodings
# /datalab/web/pyright/typeshed-fallback/stdlib/xmlrpc
# /datalab/web/pyright/typeshed-fallback/stdlib/pyexpat
# /datalab/web/pyright/typeshed-fallback/stdlib/sqlite3
# /datalab/web/pyright/typeshed-fallback/stdlib/html
# /datalab/web/pyright/typeshed-fallback/stdlib/curses
# /datalab/web/pyright/typeshed-fallback/stdlib/ensurepip
# /datalab/web/pyright/typeshed-fallback/stdlib/concurrent/futures
# /datalab/web/pyright/typeshed-fallback/stdlib/importlib/metadata
# /datalab/web/pyright/typeshed-fallback/stdlib/email/mime
# /datalab/web/pyright/typeshed-fallback/stdlib/distutils/command
# /datalab/web/pyright/typeshed-fallback/stdlib/xml/sax
# /datalab/web/pyright/typeshed-fallback/stdlib/xml/etree
# /datalab/web/pyright/typeshed-fallback/stdlib/xml/parsers
# /datalab/web/pyright/typeshed-fallback/stdlib/xml/dom
# /datalab/web/pyright/typeshed-fallback/stdlib/xml/parsers/expat
# /datalab/web/pyright/typeshed-fallback/stdlib/multiprocessing/dummy
# /datalab/web/pyright/typeshed-fallback/stdlib/lib2to3/pgen2
# /python-apt/aptsources
# /python-apt/debian
# /python-apt/typehinting
# /python-apt/tests
# /python-apt/data
# /python-apt/doc
# /python-apt/apt
# /python-apt/build
# /python-apt/python_apt.egg-info
# /python-apt/python
# /python-apt/utils
# /python-apt/po
# /python-apt/debian/source
# /python-apt/debian/tests
# /python-apt/tests/data
# /python-apt/tests/old
# /python-apt/tests/data/tagfile
# /python-apt/tests/data/test-repo2
# /python-apt/tests/data/aptsources
# /python-apt/tests/data/test-provides
# /python-apt/tests/data/test-signed-usable-repo
# /python-apt/tests/data/test-source-repo
# /python-apt/tests/data/hashsums
# /python-apt/tests/data/aptsources_ports
# /python-apt/tests/data/misc
# /python-apt/tests/data/test-repo
# /python-apt/tests/data/fake-packages
# /python-apt/tests/data/test_debs
# /python-apt/tests/data/test-provides/var
# /python-apt/tests/data/test-provides/etc
# /python-apt/tests/data/test-provides/var/lib
# /python-apt/tests/data/test-provides/var/lib/apt
# /python-apt/tests/data/test-provides/var/lib/dpkg
# /python-apt/tests/data/test-provides/var/lib/apt/lists
# /python-apt/tests/data/test-provides/etc/apt
# /python-apt/tests/data/test-signed-usable-repo/signed
# /python-apt/tests/data/test-signed-usable-repo/unsigned
# /python-apt/tests/data/test_debs/var
# /python-apt/tests/data/test_debs/etc
# /python-apt/tests/data/test_debs/var/lib
# /python-apt/tests/data/test_debs/var/lib/apt
# /python-apt/tests/data/test_debs/var/lib/dpkg
# /python-apt/tests/data/test_debs/var/lib/apt/lists
# /python-apt/tests/data/test_debs/etc/apt
# /python-apt/data/templates
# /python-apt/doc/examples
# /python-apt/doc/source
# /python-apt/doc/source/library
# /python-apt/doc/source/c++
# /python-apt/doc/source/examples
# /python-apt/doc/source/templates
# /python-apt/doc/source/whatsnew
# /python-apt/doc/source/tutorials
# /python-apt/apt/progress
# /python-apt/build/temp.linux-x86_64-cpython-311
# /python-apt/build/lib.linux-x86_64-cpython-311
# /python-apt/build/data
# /python-apt/build/temp.linux-x86_64-cpython-311/python
# /python-apt/build/lib.linux-x86_64-cpython-311/aptsources
# /python-apt/build/lib.linux-x86_64-cpython-311/apt
# /python-apt/build/lib.linux-x86_64-cpython-311/apt/progress
# /python-apt/build/data/templates
